# %%
from pipeline import make_clf
from sklearn.tree import DecisionTreeClassifier

make_clf(DecisionTreeClassifier())
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('Uniform formatting', UniformFormatting()),
#                                  ('Custom impute', CustomTransformer()),
#                                  ('preprocessor general',
#                                   ColumnTransformer(transformers=[('num',
#                                                                    Pipeline(steps=[('Outliers',
#                                                                                     Outliers(features=['Age',
#                                                                                                        'Height',
#                                                                                                        'Weight'])),
#                                                                                    ('imputer',
#                                                                                     SimpleImputer()),
# ...
